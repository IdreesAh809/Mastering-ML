# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Load Processed Data**

# %%
import pandas as pd
import numpy as np

# Load the processed data
file_path = "/content/drive/MyDrive/House_Price_Prediction/data/processed/housing_processed.csv"
df = pd.read_csv(file_path)

# Display first few rows
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88            0.982143    -0.804819           129.0
# 1    -122.22     37.86           -0.607019     2.045890          1106.0
# 2    -122.24     37.85            1.856182    -0.535746           190.0
# 3    -122.25     37.85            1.856182    -0.624215           235.0
# 4    -122.25     37.85            1.856182    -0.462404           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0       2.344766            452600.0
# 1      2401.0      1138.0       2.332238            358500.0
# 2       496.0       177.0       1.782699            352100.0
# 3       558.0       219.0       0.932968            341300.0
# 4       565.0       259.0      -0.012881            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# ...

# %% [markdown]
# **Create New Features**

# %%
# Creating new features
df["rooms_per_household"] = df["total_rooms"] / df["households"]
df["bedrooms_per_room"] = df["total_bedrooms"] / df["total_rooms"]
df["population_per_household"] = df["population"] / df["households"]

# Display first few rows to check new features
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88            0.982143    -0.804819           129.0
# 1    -122.22     37.86           -0.607019     2.045890          1106.0
# 2    -122.24     37.85            1.856182    -0.535746           190.0
# 3    -122.25     37.85            1.856182    -0.624215           235.0
# 4    -122.25     37.85            1.856182    -0.462404           280.0
#
#    population  households  median_income  median_house_value  \
# 0       322.0       126.0       2.344766            452600.0
# 1      2401.0      1138.0       2.332238            358500.0
# 2       496.0       177.0       1.782699            352100.0
# 3       558.0       219.0       0.932968            341300.0
# 4       565.0       259.0      -0.012881            342200.0
#
#    ocean_proximity_INLAND  ocean_proximity_ISLAND  ocean_proximity_NEAR BAY  \
# 0                   False                   False                      True
# ...

# %% [markdown]
# **Handling Outliers**

# %%
# Remove outliers based on the new features (if necessary)
df = df[(df["bedrooms_per_room"] < 1) & (df["rooms_per_household"] < 10)]

# %% [markdown]
# **Save the Feature-Engineered Data**

# %%
# Save the transformed dataset
save_path = "/content/drive/MyDrive/House_Price_Prediction/data/processed/housing_featured.csv"
df.to_csv(save_path, index=False)

print("Feature engineered dataset saved successfully.")
# Out:
# Feature engineered dataset saved successfully.
