# %%
import os
from google.colab import drive
import kagglehub

# 📌 Step 1: Mount Google Drive (if saving data there)
drive.mount('/content/drive')

# 📌 Step 2: Define Directory Structure
BASE_DIR = '/content/drive/MyDrive/customer-churn-prediction'
DATA_DIR = os.path.join(BASE_DIR, 'data')
RAW_DATA_DIR = os.path.join(DATA_DIR, 'raw')

# 📌 Step 3: Create Directories if They Don't Exist
os.makedirs(RAW_DATA_DIR, exist_ok=True)

# 📌 Step 4: Download Dataset from KaggleHub
print("Downloading dataset...")
dataset_path = kagglehub.dataset_download("ankitverma2010/ecommerce-customer-churn-analysis-and-prediction")

print("Dataset downloaded to:", dataset_path)
# Out:
# Mounted at /content/drive
# ...
# 100%|██████████| 532k/532k [00:00<00:00, 40.9MB/s]
# Extracting files...
# Dataset downloaded to: /root/.cache/kagglehub/datasets/ankitverma2010/ecommerce-customer-churn-analysis-and-prediction/versions/1
